# %%
from langgraph.graph import StateGraph, START, END
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = HuggingFaceEndpoint(
    repo_id="meta-llama/Llama-3.1-8B-Instruct",
    task="text-generation")
model = ChatHuggingFace(llm=llm)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**Title:** The Rise of AI in India: Opportunities, Challenges, and Future Prospects\n\n**I. Introduction**\n\n* Brief overview of the growing importance of AI globally and its potential impact on India\n* Thesis statement: AI is transforming India\'s economy, society, and daily lives, and its adoption is poised to accelerate in the coming years.\n\n**II. Current State of AI in India**\n\n* Overview of the current AI landscape in India, including:\n\t+ Government initiatives and policies promoting AI adoption\n\t+ Key players and startups in the Indian AI ecosystem\n\t+ Major sectors where AI is being applied (e.g., healthcare, finance, education)\n* Statistics and data on the growth of the Indian AI market (e.g., investments, job creation, etc.)\n\n**III. Opportunities in AI for India**\n\n* Discussion of the benefits and opportunities presented by AI in India, including:\n\t+ Enhancing healthcare and medical research\n\t+ Improving education and skill development\n\t+ Boosting economic growth and job creation\n\t+ Enhancing public services and governance\n\t+ Mitigating the effects of climate change and environmental degradation\n\n**IV. Challenges and Concerns in AI for India**\n\n* Examination of the challenges and concerns related to AI in India, including:\n\t+ Job displacement and re-skilling\n\t+ Data security and privacy concerns\n\t+ Ethical and societal implications (e.g., bias, fairness)\n\t+ Infrastructure and digital divide challenges\n\t+ Regulatory and governance frameworks\n\n**V. AI Applications in Key Sectors**\n\n* In-depth analysis of AI applications in various sectors, including:\n\t+ Healthcare: AI-powered diagnosis, treatment, and patient care\n\t+ Finance: AI-driven credit scoring, loan processing, and portfolio management\n\t+ Education: AI-assisted learning, adaptive learning, and skill development\n\t+ Agriculture: AI-powered crop monitoring, yield prediction, and precision farming\n\t+ Retail: AI-driven customer service, inventory management, and supply chain optimization\n\n**VI. Future Prospects and Roadmap for AI in India**\n\n* Discussion of the expected future trajectory of AI in India, including:\n\t+ Government and regulatory initiatives\n\t+ Private sector investments and partnerships\n\t+ Emerging technologies and innovations (e.g., AR, VR, blockchain)\n\t+ Public-private collaborations and knowledge-sharing initiatives\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India and its', 'content': '**The Rise of AI in India: Opportunities, Challenges, and Future Prospects**\n\nThe world is witnessing a technological revolution, and Artificial Intelligence (AI) is at the forefront of this transformation. As a global leader in IT and technology, India is not immune to this phenomenon. The Indian government has been actively promoting the adoption of AI, and the country is rapidly becoming a hub for AI innovation and adoption. In this blog, we will explore the current state of AI in India, its opportunities, challenges, and future prospects.\n\n**II. Current State of AI in India**\n\nThe Indian government has been actively promoting AI adoption through various initiatives, such as:\n\n* **The National AI Strategy**: Launched in 2017, this strategy aims to make India a global leader in AI by 2025.\n* **The Digital India initiative**: Aims to promote digital literacy, online services, and digital payments, with a focus on AI-powered solutions.\n* **The Start-Up India initiative**: Encourages start-ups to develop AI-powered products and services.\n\nSeveral key players and start-ups have emerged in the Indian AI ecosystem, including:\n\n* **Tata Group**: Has launched various AI-powered initiatives, such as AI-powered retail and finance solutions.\n* **Infosys**: Has established an AI-focused R&D center to develop AI-powered solutions for various industries.\n* **Zest Labs** ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **Title:** The Rise of AI in India: Opportunities, Challenges, and Future Prospects
#
# **I. Introduction**
#
# * Brief overview of the growing importance of AI globally and its potential impact on India
# * Thesis statement: AI is transforming India's economy, society, and daily lives, and its adoption is poised to accelerate in the coming years.
#
# **II. Current State of AI in India**
#
# * Overview of the current AI landscape in India, including:
# 	+ Government initiatives and policies promoting AI adoption
# 	+ Key players and startups in the Indian AI ecosystem
# 	+ Major sectors where AI is being applied (e.g., healthcare, finance, education)
# * Statistics and data on the growth of the Indian AI market (e.g., investments, job creation, etc.)
#
# **III. Opportunities in AI for India**
#
# * Discussion of the benefits and opportunities presented by AI in India, including:
# 	+ Enhancing healthcare and medical research
# 	+ Improving education and skill development
# 	+ Boosting economic growth and job creation
# 	+ Enhancing public services and governance
# 	+ Mitigating the effects of climate change and environmental degradation
#
# **IV. Challenges and Concerns in AI for India**
#
# * Examination of the challenges and concerns related to AI in India, including:
# 	+ Job displacement and re-skilling
# 	+ Data security and privacy concerns
# 	+ Ethical and societal implications (e.g., bias, fairness)
# 	+ Infrastructure and digital divide challenges
# 	+ Regulatory and governance frameworks
#
# **V. AI Applications in Key Sectors**
#
# * In-depth analysis of AI applications in various sectors, including:
# 	+ Healthcare: AI-powered diagnosis, treatment, and patient care
# 	+ Finance: AI-driven credit scoring, loan processing, and portfolio management
# 	+ Education: AI-assisted learning, adaptive learning, and skill development
# 	+ Agriculture: AI-powered crop monitoring, yield prediction, and precision farming
# 	+ Retail: AI-driven customer service, inventory management, and supply chain optimization
#
# **VI. Future Prospects and Roadmap for AI in India**
#
# * Discussion of the expected future trajectory of AI in India, including:
# 	+ Government and regulatory initiatives
# 	+ Private sector investments and partnerships
# 	+ Emerging technologies and innovations (e.g., AR, VR, blockchain)
# 	+ Public-private collaborations and knowledge-sharing initiatives
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India and its

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Opportunities, Challenges, and Future Prospects**
#
# The world is witnessing a technological revolution, and Artificial Intelligence (AI) is at the forefront of this transformation. As a global leader in IT and technology, India is not immune to this phenomenon. The Indian government has been actively promoting the adoption of AI, and the country is rapidly becoming a hub for AI innovation and adoption. In this blog, we will explore the current state of AI in India, its opportunities, challenges, and future prospects.
#
# **II. Current State of AI in India**
#
# The Indian government has been actively promoting AI adoption through various initiatives, such as:
#
# * **The National AI Strategy**: Launched in 2017, this strategy aims to make India a global leader in AI by 2025.
# * **The Digital India initiative**: Aims to promote digital literacy, online services, and digital payments, with a focus on AI-powered solutions.
# * **The Start-Up India initiative**: Encourages start-ups to develop AI-powered products and services.
#
# Several key players and start-ups have emerged in the Indian AI ecosystem, including:
#
# * **Tata Group**: Has launched various AI-powered initiatives, such as AI-powered retail and finance solutions.
# * **Infosys**: Has established an AI-focused R&D center to develop AI-powered solutions for various industries.
# * **Zest Labs**: A start-up that offers AI-powered solutions for agriculture, healthcare, and finance.
#
# Major sectors where AI is being applied include:
#
# * **Healthcare**: AI-powered diagnosis, treatment, and patient care.
# * **Finance**: AI-driven credit scoring, loan processing, and portfolio management.
# * **Education**: AI-assisted learning, adaptive learning, and skill development.
#
# Statistics and data on the growth of the Indian AI market:
#
# * **Investments**: The Indian AI market has seen significant investments, with a total of $1.1 billion invested in 2020 alone.
# * **Job creation**: AI is expected to create over 1.5 million jobs in India by 2025.
# * **Growth rate**: The Indian AI market is expected to grow at a CAGR of 30% from 2020 to 2025.
#
# **III. Opportunities in AI for India**
#
# AI offers numerous benefits and opportunities for India, including:
#
# * **Enhancing healthcare and medical research**: AI can help improve diagnosis, treatment, and patient care.
# * **Improving education and skill development**: AI can assist in adaptive learning, skill development, and career counseling.
# *
